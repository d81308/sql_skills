# %% [markdown]
# # Library

# %%
import psycopg2

# %% [markdown]
# ## Using psycopg2

# %%
#define info for connection
db_name = 'started'
db_user = 'postgres'
db_password = 'd9982951'
db_host = '127.0.0.1'
db_port = 5433
#start to connect
conn = psycopg2.connect(
    database = db_name,
    user = db_user,
    password = db_password,
    host = db_host,
    port = db_port
)

# %%
#create a cursor
cur = conn.cursor()

# %% [markdown]
# ## magic method

# %%
# %load_ext sql

# %% [markdown]
# #. %sql postgresql://{user}:{password}@{host}:{port}/{database}

# %%
# %sql postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}

# %% [markdown]
# ## change para in system, wal_level

# %%
# %%sql
#     show wal_level
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# 1 rows affected.
# [('replica',)]

# %%
# %%sql
#     ALTER SYSTEM SET wal_level = 'logical'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# Done.
# []

# %%
# %%sql
#     show wal_level
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# 1 rows affected.
# [('replica',)]

# %% [markdown]
# ## pg_tables

# %%
# %%sql
#     select *
#     from pg_catalog.pg_class
#     where relname like '%table%'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# 29 rows affected.
# [(3118, 'pg_foreign_table', 11, 10082, 0, 10, 2, 3118, 0, 0, 0.0, 0, 4153, True, False, 'p', 'r', 3, 0, False, False, False, False, False, True, 'n', False, 0, '716', '1', '{postgres=arwdDxt/postgres,=r/postgres}', None, None),
#  (2697, 'pg_tablespace_oid_index', 11, 0, 0, 10, 403, 0, 1664, 2, 2.0, 0, 0, False, True, 'p', 'i', 1, 0, False, False, False, False, False, True, 'n', False, 0, '0', '0', None, None, None),
#  (2698, 'pg_tablespace_spcname_index', 11, 0, 0, 10, 403, 0, 1664, 2, 2.0, 0, 0, False, True, 'p', 'i', 1, 0, False, False, False, False, False, True, 'n', False, 0, '0', '0', None, None, None),
#  (3119, 'pg_foreign_table_relid_index', 11, 0, 0, 10, 403, 3119, 0, 1, 0.0, 0, 0, False, False, 'p', 'i', 1, 0, False, False, False, False, False, True, 'n', False, 0, '0', '0', None, None, None),
# ...

# %% [markdown]
#     #alter table security, and check security status

# %%
# %%sql
#     select *
#     from pg_catalog.pg_tables
#     where schemaname = 'employee_data_groupby'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# 5 rows affected.
# [('employee_data_groupby', 'job_history', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'jobs', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'departments', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'employees', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'locations', 'postgres', None, False, False, False, False)]

# %%
# %%sql
#     ALTER TABLE employee_data_groupby.employees ENABLE ROW LEVEL SECURITY
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# Done.
# []

# %%
# %%sql
#     select *
#     from pg_catalog.pg_tables
#     where schemaname = 'employee_data_groupby'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# 5 rows affected.
# [('employee_data_groupby', 'job_history', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'jobs', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'departments', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'locations', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'employees', 'postgres', None, False, False, False, True)]

# %% [markdown]
#     #pg_settings

# %%
# %%sql
#     select *
#     from pg_catalog.pg_settings
#     where name = 'wal_level'
#     limit 3
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# 1 rows affected.
# [('wal_level', 'replica', None, 'Write-Ahead Log / Settings', 'Sets the level of information written to the WAL.', None, 'postmaster', 'enum', 'default', None, None, ['minimal', 'replica', 'logical'], 'replica', 'replica', None, None, False)]

# %% [markdown]
#     #change table name in pg_tables, change jobs
#     may show have no force to do.

# %%
# %%sql
#     update pg_tables
#     set tablename = 'jobs_info'
#     where tablename = 'jobs'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# (psycopg2.errors.ObjectNotInPrerequisiteState) cannot update view "pg_tables"
# DETAIL:  Views that do not select from a single table or view are not automatically updatable.
# HINT:  To enable updating the view, provide an INSTEAD OF UPDATE trigger or an unconditional ON UPDATE DO INSTEAD rule.
#
# [SQL: update pg_tables
#     set tablename = 'jobs_info'
#     where tablename = 'jobs']
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
#     #if try empolyee, row secuirty can do this tasks?
#     still can't

# %%
# %%sql
#     update pg_tables
#     set tablename = 'employees_info'
#     where tablename = 'employees'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# (psycopg2.errors.ObjectNotInPrerequisiteState) cannot update view "pg_tables"
# DETAIL:  Views that do not select from a single table or view are not automatically updatable.
# HINT:  To enable updating the view, provide an INSTEAD OF UPDATE trigger or an unconditional ON UPDATE DO INSTEAD rule.
#
# [SQL: update pg_tables
#     set tablename = 'employees_info'
#     where tablename = 'employees']
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
#     #alter table name by DBA user, not pg_table
#     #and check pg_tables agian

# %%
# %%sql
#     ALTER TABLE  employee_data_groupby.jobs RENAME TO jobs_info
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# Done.
# []

# %%
# %%sql
#     select *
#     from pg_catalog.pg_tables
#     where schemaname = 'employee_data_groupby'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5433/started
# 5 rows affected.
# [('employee_data_groupby', 'job_history', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'departments', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'locations', 'postgres', None, False, False, False, False),
#  ('employee_data_groupby', 'employees', 'postgres', None, False, False, False, True),
#  ('employee_data_groupby', 'jobs_info', 'postgres', None, False, False, False, False)]

# %% [markdown]
#     #the jobs change to jobs_info success
